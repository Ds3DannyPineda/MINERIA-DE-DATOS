# %% [markdown]
# <!--Header-->
# <div>
#     <div class="row" style="color: #4D4D4D;font-size: 15px;padding-bottom: 20px">
#         <div class="col-md-7">
#             <img src="https://www.tecazuay.edu.ec/wp-content/uploads/2023/07/LOGO-RECTANGULAR_SIN-FONDO.png" alt="Logo TECAZUAY" width="100%" class="img-responsive" style="margin:20px 0px 0px">
#         </div>
#         <div class="col-md-5">
#             <h1 style="margin:15px 0px 0px;font-size: 40px;">EVALUACIÓN DE MODELOS</h1>
#             <div style="text-align:left;margin-top: 5px;"></div>
#         </div>
#     </div>
#     <div class="row" style="background: #FCB517;padding: 10px 20px;">
#         <div class="col-md-6">
#             <div>CICLO: M3A</div>
#         </div>
#         <div class="col-md-6">
#             <div style="text-align:right;">Autor: Verónica Chimbo <span style="margin-left: 30px;"></span></div>
#         </div>
#         <div style="text-align:right;">Carrera: TECNOLOGÍA SUPERIOR EN BIG DATA <span style="margin-left: 30px;"></span></div>
#          <div style="text-align:right;">Estudiante: DANNY PINEDA  <span style="margin-left: 30px;"></span></div>
#           <div style="text-align:right;">Fecha:01/08/2024  <span style="margin-left: 30px;"></span></div>
#         </div>
#     </div>
# </div>
# <!--/Header-->

# %% [markdown]
# # EVALUACIÓN DE MODELOS
# La evaluación de modelos en minería de datos es crucial para entender cómo se comporta un modelo y qué tan bien generaliza a datos no vistos.

# %%
import pandas as pd

df_estudiantes = pd.DataFrame({
    'cedula': [
        '0106605017', '0106605017', '0106605017',
        '0302365440', '0302365440', '0302365440', '0302365440',
        '0150564078', '0150564078', '0150564078',
        '0107973687', '0107973687', '0107973687', '0107973687', '0107973687', '0107973687',
        '0151150224', '0151150224',
        '0107957144', '0107957144',
        '1401416993', '1401416993', '1401416993', '1401416993',
        '0106361959', '0106361959', '0106361959', '0106361959',
        '0107416927', '0107416927',
        '0107915126', '0107915126', '0107915126',
        '0106422496', '0106422496', '0106422496', '0106422496', '0106422496',
        '0105467815', '0105467815', '0105467815', '0105467815', '0105467815', '0105467815'
    ],
    'nombre': [
        'ASTUDILLO LANDIVAR CARLOS JOSUE', 'ASTUDILLO LANDIVAR CARLOS JOSUE', 'ASTUDILLO LANDIVAR CARLOS JOSUE',
        'ASTUDILLO PARAMO JONNATHAN RENE', 'ASTUDILLO PARAMO JONNATHAN RENE', 'ASTUDILLO PARAMO JONNATHAN RENE', 'ASTUDILLO PARAMO JONNATHAN RENE',
        'AUQUILLA TENESACA DANNY ALEXANDER', 'AUQUILLA TENESACA DANNY ALEXANDER', 'AUQUILLA TENESACA DANNY ALEXANDER',
        'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL',
        'CALVA MOROCHO JOEL ALEXANDER', 'CALVA MOROCHO JOEL ALEXANDER',
        'GOMEZ MOLINA PAULA DAYANNA', 'GOMEZ MOLINA PAULA DAYANNA',
        'LOJANO JARA MAICOL LEONARDO', 'LOJANO JARA MAICOL LEONARDO', 'LOJANO JARA MAICOL LEONARDO', 'LOJANO JARA MAICOL LEONARDO',
        'LOJANO RUIZ KEVIN DANIEL', 'LOJANO RUIZ KEVIN DANIEL', 'LOJANO RUIZ KEVIN DANIEL', 'LOJANO RUIZ KEVIN DANIEL',
        'MUÑOZ ASTUDILLO JOSE RICARDO', 'MUÑOZ ASTUDILLO JOSE RICARDO',
        'PINEDA NIETO DANNY PAUL', 'PINEDA NIETO DANNY PAUL', 'PINEDA NIETO DANNY PAUL',
        'RODRIGUEZ PERALTA PAUL ANDRES', 'RODRIGUEZ PERALTA PAUL ANDRES', 'RODRIGUEZ PERALTA PAUL ANDRES', 'RODRIGUEZ PERALTA PAUL ANDRES', 'RODRIGUEZ PERALTA PAUL ANDRES',
        'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL'
    ],
    'asignatura': [
        'Emprendimiento', 'Inteligencia de Negocios', 'Aprendizaje de Máquina', 'Etica Profesional',
        'Minería de Datos', 'Emprendimiento', 'Marcos de referencia', 'Aprendizaje de Máquina',
        'Inteligencia de Negocios', 'Etica Profesional', 'Emprendimiento', 'Marcos de referencia',
        'Minería de Datos', 'Inteligencia de Negocios', 'Aprendizaje de Máquina', 'Etica Profesional',
        'Marcos de referencia', 'Minería de Datos', 'Emprendimiento', 'Inteligencia de Negocios',
        'Aprendizaje de Máquina', 'Etica Profesional', 'Marcos de referencia', 'Minería de Datos',
        'Emprendimiento', 'Inteligencia de Negocios', 'Aprendizaje de Máquina', 'Etica Profesional',
        'Minería de Datos', 'Marcos de referencia', 'Inteligencia de Negocios', 'Aprendizaje de Máquina',
        'Etica Profesional', 'Minería de Datos', 'Marcos de referencia', 'Inteligencia de Negocios',
        'Aprendizaje de Máquina', 'Etica Profesional', 'Marcos de referencia', 'Minería de Datos',
        'Emprendimiento', 'Inteligencia de Negocios', 'Aprendizaje de Máquina', 'Etica Profesional'
    ],
    'nota_final': [
        85, 90, 88, 80, 75, 85, 90, 95, 92, 88,
        90, 93, 91, 85, 88, 84, 92, 95, 87, 88,
        82, 90, 85, 80, 87, 90, 93, 90, 88, 85,
        87, 90, 95, 80, 85, 87, 92, 88, 90, 94,
        85, 88, 92, 90
    ]
})

# Muestra los DataFrames para verificar los cambios
df_estudiantes
# Out:
#         cedula                             nombre                asignatura  \
# 0   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE            Emprendimiento
# 1   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE  Inteligencia de Negocios
# 2   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE    Aprendizaje de Máquina
# 3   0302365440    ASTUDILLO PARAMO JONNATHAN RENE         Etica Profesional
# 4   0302365440    ASTUDILLO PARAMO JONNATHAN RENE          Minería de Datos
# 5   0302365440    ASTUDILLO PARAMO JONNATHAN RENE            Emprendimiento
# 6   0302365440    ASTUDILLO PARAMO JONNATHAN RENE      Marcos de referencia
# 7   0150564078  AUQUILLA TENESACA DANNY ALEXANDER    Aprendizaje de Máquina
# 8   0150564078  AUQUILLA TENESACA DANNY ALEXANDER  Inteligencia de Negocios
# 9   0150564078  AUQUILLA TENESACA DANNY ALEXANDER         Etica Profesional
# 10  0107973687     CABRERA BARBECHO VICTOR MANUEL            Emprendimiento
# ...

# %%
df_diagnostico = pd.DataFrame({
    'cedula': [
        '0106605017', '0106605017', '0106605017',
        '0302365440', '0302365440', '0302365440', '0302365440',
        '0150564078', '0150564078', '0150564078',
        '0107973687', '0107973687', '0107973687', '0107973687', '0107973687', '0107973687',
        '0151150224', '0151150224',
        '0107957144', '0107957144',
        '1401416993', '1401416993', '1401416993', '1401416993',
        '0106361959', '0106361959', '0106361959', '0106361959',
        '0107416927', '0107416927',
        '0107915126', '0107915126', '0107915126',
        '0106422496', '0106422496', '0106422496', '0106422496', '0106422496',
        '0105467815', '0105467815', '0105467815', '0105467815', '0105467815', '0105467815'
    ],
    'nombre': [
        'ASTUDILLO LANDIVAR CARLOS JOSUE', 'ASTUDILLO LANDIVAR CARLOS JOSUE', 'ASTUDILLO LANDIVAR CARLOS JOSUE',
        'ASTUDILLO PARAMO JONNATHAN RENE', 'ASTUDILLO PARAMO JONNATHAN RENE', 'ASTUDILLO PARAMO JONNATHAN RENE', 'ASTUDILLO PARAMO JONNATHAN RENE',
        'AUQUILLA TENESACA DANNY ALEXANDER', 'AUQUILLA TENESACA DANNY ALEXANDER', 'AUQUILLA TENESACA DANNY ALEXANDER',
        'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL',
        'CALVA MOROCHO JOEL ALEXANDER', 'CALVA MOROCHO JOEL ALEXANDER',
        'GOMEZ MOLINA PAULA DAYANNA', 'GOMEZ MOLINA PAULA DAYANNA',
        'LOJANO JARA MAICOL LEONARDO', 'LOJANO JARA MAICOL LEONARDO', 'LOJANO JARA MAICOL LEONARDO', 'LOJANO JARA MAICOL LEONARDO',
        'LOJANO RUIZ KEVIN DANIEL', 'LOJANO RUIZ KEVIN DANIEL', 'LOJANO RUIZ KEVIN DANIEL', 'LOJANO RUIZ KEVIN DANIEL',
        'MUÑOZ ASTUDILLO JOSE RICARDO', 'MUÑOZ ASTUDILLO JOSE RICARDO',
        'PINEDA NIETO DANNY PAUL', 'PINEDA NIETO DANNY PAUL', 'PINEDA NIETO DANNY PAUL',
        'RODRIGUEZ PERALTA PAUL ANDRES', 'RODRIGUEZ PERALTA PAUL ANDRES', 'RODRIGUEZ PERALTA PAUL ANDRES', 'RODRIGUEZ PERALTA PAUL ANDRES', 'RODRIGUEZ PERALTA PAUL ANDRES',
        'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL'
    ],
    'asignatura': [
        'Etica Profesional', 'Aprendizaje de Máquina', 'Inteligencia de Negocios', 'Minería de Datos',
        'Marcos de referencia', 'Emprendimiento', 'Aprendizaje de Máquina', 'Inteligencia de Negocios',
        'Etica Profesional', 'Minería de Datos', 'Marcos de referencia', 'Inteligencia de Negocios',
        'Aprendizaje de Máquina', 'Etica Profesional', 'Minería de Datos', 'Marcos de referencia',
        'Inteligencia de Negocios', 'Aprendizaje de Máquina', 'Etica Profesional', 'Minería de Datos',
        'Marcos de referencia', 'Inteligencia de Negocios', 'Aprendizaje de Máquina', 'Etica Profesional',
        'Minería de Datos', 'Marcos de referencia', 'Inteligencia de Negocios', 'Aprendizaje de Máquina',
        'Etica Profesional', 'Minería de Datos', 'Marcos de referencia', 'Inteligencia de Negocios',
        'Aprendizaje de Máquina', 'Etica Profesional', 'Minería de Datos', 'Marcos de referencia',
        'Inteligencia de Negocios', 'Aprendizaje de Máquina', 'Etica Profesional', 'Minería de Datos',
        'Marcos de referencia', 'Inteligencia de Negocios', 'Aprendizaje de Máquina', 'Etica Profesional'
    ],
    'nota_diagnostico': [
        80, 85, 87, 78, 82, 80, 85, 90, 88, 87,
        80, 85, 87, 78, 82, 80, 85, 90, 88, 87,
        80, 85, 87, 78, 82, 80, 85, 90, 88, 87,
        80, 85, 87, 78, 82, 80, 85, 90, 88, 87,
        80, 85, 87, 78
    ]
})

df_diagnostico
# Out:
#         cedula                             nombre                asignatura  \
# 0   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE         Etica Profesional
# 1   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE    Aprendizaje de Máquina
# 2   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE  Inteligencia de Negocios
# 3   0302365440    ASTUDILLO PARAMO JONNATHAN RENE          Minería de Datos
# 4   0302365440    ASTUDILLO PARAMO JONNATHAN RENE      Marcos de referencia
# 5   0302365440    ASTUDILLO PARAMO JONNATHAN RENE            Emprendimiento
# 6   0302365440    ASTUDILLO PARAMO JONNATHAN RENE    Aprendizaje de Máquina
# 7   0150564078  AUQUILLA TENESACA DANNY ALEXANDER  Inteligencia de Negocios
# 8   0150564078  AUQUILLA TENESACA DANNY ALEXANDER         Etica Profesional
# 9   0150564078  AUQUILLA TENESACA DANNY ALEXANDER          Minería de Datos
# 10  0107973687     CABRERA BARBECHO VICTOR MANUEL      Marcos de referencia
# ...

# %%
df_interciclo = pd.DataFrame({
    'cedula': [
        '0106605017', '0106605017', '0106605017',
        '0302365440', '0302365440', '0302365440', '0302365440',
        '0150564078', '0150564078', '0150564078',
        '0107973687', '0107973687', '0107973687', '0107973687', '0107973687', '0107973687',
        '0151150224', '0151150224',
        '0107957144', '0107957144',
        '1401416993', '1401416993', '1401416993', '1401416993',
        '0106361959', '0106361959', '0106361959', '0106361959',
        '0107416927', '0107416927',
        '0107915126', '0107915126', '0107915126',
        '0106422496', '0106422496', '0106422496', '0106422496', '0106422496',
        '0105467815', '0105467815', '0105467815', '0105467815', '0105467815', '0105467815'
    ],
    'nombre': [
        'ASTUDILLO LANDIVAR CARLOS JOSUE', 'ASTUDILLO LANDIVAR CARLOS JOSUE', 'ASTUDILLO LANDIVAR CARLOS JOSUE',
        'ASTUDILLO PARAMO JONNATHAN RENE', 'ASTUDILLO PARAMO JONNATHAN RENE', 'ASTUDILLO PARAMO JONNATHAN RENE', 'ASTUDILLO PARAMO JONNATHAN RENE',
        'AUQUILLA TENESACA DANNY ALEXANDER', 'AUQUILLA TENESACA DANNY ALEXANDER', 'AUQUILLA TENESACA DANNY ALEXANDER',
        'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL',
        'CALVA MOROCHO JOEL ALEXANDER', 'CALVA MOROCHO JOEL ALEXANDER',
        'GOMEZ MOLINA PAULA DAYANNA', 'GOMEZ MOLINA PAULA DAYANNA',
        'LOJANO JARA MAICOL LEONARDO', 'LOJANO JARA MAICOL LEONARDO', 'LOJANO JARA MAICOL LEONARDO', 'LOJANO JARA MAICOL LEONARDO',
        'LOJANO RUIZ KEVIN DANIEL', 'LOJANO RUIZ KEVIN DANIEL', 'LOJANO RUIZ KEVIN DANIEL', 'LOJANO RUIZ KEVIN DANIEL',
        'MUÑOZ ASTUDILLO JOSE RICARDO', 'MUÑOZ ASTUDILLO JOSE RICARDO',
        'PINEDA NIETO DANNY PAUL', 'PINEDA NIETO DANNY PAUL', 'PINEDA NIETO DANNY PAUL',
        'RODRIGUEZ PERALTA PAUL ANDRES', 'RODRIGUEZ PERALTA PAUL ANDRES', 'RODRIGUEZ PERALTA PAUL ANDRES', 'RODRIGUEZ PERALTA PAUL ANDRES', 'RODRIGUEZ PERALTA PAUL ANDRES',
        'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL'
    ],
    'asignatura': [
        'Etica Profesional', 'Aprendizaje de Máquina', 'Inteligencia de Negocios', 'Minería de Datos',
        'Marcos de referencia', 'Emprendimiento', 'Aprendizaje de Máquina', 'Inteligencia de Negocios',
        'Etica Profesional', 'Minería de Datos', 'Marcos de referencia', 'Inteligencia de Negocios',
        'Aprendizaje de Máquina', 'Etica Profesional', 'Minería de Datos', 'Marcos de referencia',
        'Inteligencia de Negocios', 'Aprendizaje de Máquina', 'Etica Profesional', 'Minería de Datos',
        'Marcos de referencia', 'Inteligencia de Negocios', 'Aprendizaje de Máquina', 'Etica Profesional',
        'Minería de Datos', 'Marcos de referencia', 'Inteligencia de Negocios', 'Aprendizaje de Máquina',
        'Etica Profesional', 'Minería de Datos', 'Marcos de referencia', 'Inteligencia de Negocios',
        'Aprendizaje de Máquina', 'Etica Profesional', 'Minería de Datos', 'Marcos de referencia',
        'Inteligencia de Negocios', 'Aprendizaje de Máquina', 'Etica Profesional', 'Minería de Datos',
        'Marcos de referencia', 'Inteligencia de Negocios', 'Aprendizaje de Máquina', 'Etica Profesional'
    ],
    'nota_interciclo': [
        88, 92, 89, 84, 88, 82, 90, 93, 91, 90,
        88, 92, 89, 84, 88, 82, 90, 93, 91, 90,
        88, 92, 89, 84, 88, 82, 90, 93, 91, 90,
        88, 92, 89, 84, 88, 82, 90, 93, 91, 90,
        88, 92, 89, 84
    ],
    'asistencia': [
        80, 77, 85, 90, 88, 76, 92, 81, 87, 95,
        78, 82, 87, 95, 80, 90, 85, 77, 88, 92,
        80, 77, 85, 90, 87, 82, 90, 93, 80, 85,
        90, 82, 90, 93, 87, 80, 82, 85, 90, 88,
        90, 85, 87, 80
    ]
})

df_interciclo
# Out:
#         cedula                             nombre                asignatura  \
# 0   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE         Etica Profesional
# 1   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE    Aprendizaje de Máquina
# 2   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE  Inteligencia de Negocios
# 3   0302365440    ASTUDILLO PARAMO JONNATHAN RENE          Minería de Datos
# 4   0302365440    ASTUDILLO PARAMO JONNATHAN RENE      Marcos de referencia
# 5   0302365440    ASTUDILLO PARAMO JONNATHAN RENE            Emprendimiento
# 6   0302365440    ASTUDILLO PARAMO JONNATHAN RENE    Aprendizaje de Máquina
# 7   0150564078  AUQUILLA TENESACA DANNY ALEXANDER  Inteligencia de Negocios
# 8   0150564078  AUQUILLA TENESACA DANNY ALEXANDER         Etica Profesional
# 9   0150564078  AUQUILLA TENESACA DANNY ALEXANDER          Minería de Datos
# 10  0107973687     CABRERA BARBECHO VICTOR MANUEL      Marcos de referencia
# ...

# %%
import pandas as pd

df_final = pd.DataFrame({
    'cedula': [
        '0106605017', '0106605017', '0106605017',
        '0302365440', '0302365440', '0302365440', '0302365440',
        '0150564078', '0150564078', '0150564078',
        '0107973687', '0107973687', '0107973687', '0107973687', '0107973687', '0107973687',
        '0151150224', '0151150224',
        '0107957144', '0107957144',
        '1401416993', '1401416993', '1401416993', '1401416993',
        '0106361959', '0106361959', '0106361959', '0106361959',
        '0107416927', '0107416927',
        '0107915126', '0107915126', '0107915126',
        '0106422496', '0106422496', '0106422496', '0106422496', '0106422496',
        '0105467815', '0105467815', '0105467815', '0105467815', '0105467815', '0105467815'
    ],
    'nombre': [
        'ASTUDILLO LANDIVAR CARLOS JOSUE', 'ASTUDILLO LANDIVAR CARLOS JOSUE', 'ASTUDILLO LANDIVAR CARLOS JOSUE',
        'ASTUDILLO PARAMO JONNATHAN RENE', 'ASTUDILLO PARAMO JONNATHAN RENE', 'ASTUDILLO PARAMO JONNATHAN RENE', 'ASTUDILLO PARAMO JONNATHAN RENE',
        'AUQUILLA TENESACA DANNY ALEXANDER', 'AUQUILLA TENESACA DANNY ALEXANDER', 'AUQUILLA TENESACA DANNY ALEXANDER',
        'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL', 'CABRERA BARBECHO VICTOR MANUEL',
        'CALVA MOROCHO JOEL ALEXANDER', 'CALVA MOROCHO JOEL ALEXANDER',
        'GOMEZ MOLINA PAULA DAYANNA', 'GOMEZ MOLINA PAULA DAYANNA',
        'LOJANO JARA MAICOL LEONARDO', 'LOJANO JARA MAICOL LEONARDO', 'LOJANO JARA MAICOL LEONARDO', 'LOJANO JARA MAICOL LEONARDO',
        'LOJANO RUIZ KEVIN DANIEL', 'LOJANO RUIZ KEVIN DANIEL', 'LOJANO RUIZ KEVIN DANIEL', 'LOJANO RUIZ KEVIN DANIEL',
        'MUÑOZ ASTUDILLO JOSE RICARDO', 'MUÑOZ ASTUDILLO JOSE RICARDO',
        'PINEDA NIETO DANNY PAUL', 'PINEDA NIETO DANNY PAUL', 'PINEDA NIETO DANNY PAUL',
        'RODRIGUEZ PERALTA PAUL ANDRES', 'RODRIGUEZ PERALTA PAUL ANDRES', 'RODRIGUEZ PERALTA PAUL ANDRES', 'RODRIGUEZ PERALTA PAUL ANDRES', 'RODRIGUEZ PERALTA PAUL ANDRES',
        'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL', 'SAQUICELA ABRIL PABLO ARIEL'
    ],
    'asignatura': [
        'Etica Profesional', 'Aprendizaje de Máquina', 'Inteligencia de Negocios', 'Minería de Datos',
        'Marcos de referencia', 'Emprendimiento', 'Aprendizaje de Máquina', 'Inteligencia de Negocios',
        'Etica Profesional', 'Minería de Datos', 'Marcos de referencia', 'Inteligencia de Negocios',
        'Aprendizaje de Máquina', 'Etica Profesional', 'Minería de Datos', 'Marcos de referencia',
        'Inteligencia de Negocios', 'Aprendizaje de Máquina', 'Etica Profesional', 'Minería de Datos',
        'Marcos de referencia', 'Inteligencia de Negocios', 'Aprendizaje de Máquina', 'Etica Profesional',
        'Minería de Datos', 'Marcos de referencia', 'Inteligencia de Negocios', 'Aprendizaje de Máquina',
        'Etica Profesional', 'Minería de Datos', 'Marcos de referencia', 'Inteligencia de Negocios',
        'Aprendizaje de Máquina', 'Etica Profesional', 'Minería de Datos', 'Marcos de referencia',
        'Inteligencia de Negocios', 'Aprendizaje de Máquina', 'Etica Profesional', 'Minería de Datos',
        'Marcos de referencia', 'Inteligencia de Negocios', 'Aprendizaje de Máquina', 'Etica Profesional'
    ],
    'nota_final2': [
        90, 85, 88, 87, 80, 82, 90, 93, 92, 88,
        90, 85, 87, 80, 82, 90, 93, 88, 87, 90,
        85, 80, 90, 85, 80, 82, 90, 93, 88, 87,
        90, 85, 87, 80, 82, 90, 93, 88, 87, 90,
        85, 80, 90, 85
    ],
    'asistencia2': [
        79, 85, 94, 78, 87, 80, 97, 91, 82, 99,
        76, 84, 90, 88, 95, 79, 83, 92, 86, 100,
        77, 81, 96, 89, 75, 93, 80, 86, 97, 82,
        84, 98, 77, 88, 91, 95, 79, 83, 90, 89,
        82, 98, 77, 80
    ]
})

df_final
# Out:
#         cedula                             nombre                asignatura  \
# 0   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE         Etica Profesional
# 1   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE    Aprendizaje de Máquina
# 2   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE  Inteligencia de Negocios
# 3   0302365440    ASTUDILLO PARAMO JONNATHAN RENE          Minería de Datos
# 4   0302365440    ASTUDILLO PARAMO JONNATHAN RENE      Marcos de referencia
# 5   0302365440    ASTUDILLO PARAMO JONNATHAN RENE            Emprendimiento
# 6   0302365440    ASTUDILLO PARAMO JONNATHAN RENE    Aprendizaje de Máquina
# 7   0150564078  AUQUILLA TENESACA DANNY ALEXANDER  Inteligencia de Negocios
# 8   0150564078  AUQUILLA TENESACA DANNY ALEXANDER         Etica Profesional
# 9   0150564078  AUQUILLA TENESACA DANNY ALEXANDER          Minería de Datos
# 10  0107973687     CABRERA BARBECHO VICTOR MANUEL      Marcos de referencia
# ...

# %%
# Realiza las uniones
df_combined = df_estudiantes \
    .merge(df_diagnostico, on=['cedula', 'nombre', 'asignatura'], how='left') \
    .merge(df_interciclo, on=['cedula', 'nombre', 'asignatura'], how='left') \
    .merge(df_final, on=['cedula', 'nombre', 'asignatura'], how='left')

# %%
# Mostrar el DataFrame combinado
print("DataFrame combinado:")
df_combined
# Out:
# DataFrame combinado:
#         cedula                             nombre                asignatura  \
# 0   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE            Emprendimiento
# 1   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE  Inteligencia de Negocios
# 2   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE    Aprendizaje de Máquina
# 3   0302365440    ASTUDILLO PARAMO JONNATHAN RENE         Etica Profesional
# 4   0302365440    ASTUDILLO PARAMO JONNATHAN RENE          Minería de Datos
# 5   0302365440    ASTUDILLO PARAMO JONNATHAN RENE            Emprendimiento
# 6   0302365440    ASTUDILLO PARAMO JONNATHAN RENE      Marcos de referencia
# 7   0150564078  AUQUILLA TENESACA DANNY ALEXANDER    Aprendizaje de Máquina
# 8   0150564078  AUQUILLA TENESACA DANNY ALEXANDER  Inteligencia de Negocios
# 9   0150564078  AUQUILLA TENESACA DANNY ALEXANDER         Etica Profesional
# 10  0107973687     CABRERA BARBECHO VICTOR MANUEL            Emprendimiento
# ...

# %%
df_combined.isnull().sum()
# Out:
# cedula               0
# nombre               0
# asignatura           0
# nota_final           0
# nota_diagnostico    14
# nota_interciclo     14
# asistencia          14
# nota_final2         14
# asistencia2         14
# dtype: int64

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cedula            58 non-null     object
#  1   nombre            58 non-null     object
#  2   asignatura        58 non-null     object
#  3   nota_final        58 non-null     int64
#  4   nota_diagnostico  44 non-null     float64
#  5   nota_interciclo   44 non-null     float64
#  6   asistencia        44 non-null     float64
#  7   nota_final2       44 non-null     float64
#  8   asistencia2       44 non-null     float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 4.2+ KB

# %%
# Calcular el promedio de cada columna específica con dos decimales
promedio_nota_diagnostico = df_combined['nota_diagnostico'].mean()
promedio_nota_interciclo = df_combined['nota_interciclo'].mean()
promedio_asistencia = df_combined['asistencia'].mean()
promedio_nota_final2 = df_combined['nota_final2'].mean()
promedio_asistencia2 = df_combined['asistencia2'].mean()

# Redondear los promedios a dos decimales
promedio_nota_diagnostico = round(promedio_nota_diagnostico, 2)
promedio_nota_interciclo = round(promedio_nota_interciclo, 2)
promedio_asistencia = round(promedio_asistencia, 2)
promedio_nota_final2 = round(promedio_nota_final2, 2)
promedio_asistencia2 = round(promedio_asistencia2, 2)

# Reemplazar los NaN en cada columna con el promedio correspondiente
df_combined['nota_diagnostico'].fillna(promedio_nota_diagnostico, inplace=True)
df_combined['nota_interciclo'].fillna(promedio_nota_interciclo, inplace=True)
df_combined['asistencia'].fillna(promedio_asistencia, inplace=True)
df_combined['nota_final2'].fillna(promedio_nota_final2, inplace=True)
df_combined['asistencia2'].fillna(promedio_asistencia2, inplace=True)

# %%
df_combined.isnull().sum()
# Out:
# cedula              0
# nombre              0
# asignatura          0
# nota_final          0
# nota_diagnostico    0
# nota_interciclo     0
# asistencia          0
# nota_final2         0
# asistencia2         0
# dtype: int64

# %%
df_combined
# Out:
#         cedula                             nombre                asignatura  \
# 0   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE            Emprendimiento
# 1   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE  Inteligencia de Negocios
# 2   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE    Aprendizaje de Máquina
# 3   0302365440    ASTUDILLO PARAMO JONNATHAN RENE         Etica Profesional
# 4   0302365440    ASTUDILLO PARAMO JONNATHAN RENE          Minería de Datos
# 5   0302365440    ASTUDILLO PARAMO JONNATHAN RENE            Emprendimiento
# 6   0302365440    ASTUDILLO PARAMO JONNATHAN RENE      Marcos de referencia
# 7   0150564078  AUQUILLA TENESACA DANNY ALEXANDER    Aprendizaje de Máquina
# 8   0150564078  AUQUILLA TENESACA DANNY ALEXANDER  Inteligencia de Negocios
# 9   0150564078  AUQUILLA TENESACA DANNY ALEXANDER         Etica Profesional
# 10  0107973687     CABRERA BARBECHO VICTOR MANUEL            Emprendimiento
# ...

# %%
# Calcular el promedio de las columnas asistencia y asistencia2
df_combined['Total_Asistencia'] = df_combined[['asistencia', 'asistencia2']].mean(axis=1)

# %%
df_combined
# Out:
#         cedula                             nombre                asignatura  \
# 0   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE            Emprendimiento
# 1   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE  Inteligencia de Negocios
# 2   0106605017    ASTUDILLO LANDIVAR CARLOS JOSUE    Aprendizaje de Máquina
# 3   0302365440    ASTUDILLO PARAMO JONNATHAN RENE         Etica Profesional
# 4   0302365440    ASTUDILLO PARAMO JONNATHAN RENE          Minería de Datos
# 5   0302365440    ASTUDILLO PARAMO JONNATHAN RENE            Emprendimiento
# 6   0302365440    ASTUDILLO PARAMO JONNATHAN RENE      Marcos de referencia
# 7   0150564078  AUQUILLA TENESACA DANNY ALEXANDER    Aprendizaje de Máquina
# 8   0150564078  AUQUILLA TENESACA DANNY ALEXANDER  Inteligencia de Negocios
# 9   0150564078  AUQUILLA TENESACA DANNY ALEXANDER         Etica Profesional
# 10  0107973687     CABRERA BARBECHO VICTOR MANUEL            Emprendimiento
# ...

# %%
# Importar bibliotecas necesarias
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Preparar los datos para el modelo
X = df_combined[['nota_final', 'nota_diagnostico', 'nota_interciclo']]
y = df_combined['nota_final2']

# %%
# Dividir los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Crear un modelo de regresión lineal
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Realizar predicciones
y_pred = model.predict(X_test)

# %% [markdown]
# # Error Cuadrático Medio (MSE)
# Descripción: Mide el promedio de los cuadrados de los errores (diferencias entre valores predichos y reales). Penaliza los errores grandes más severamente.

# %%
# Evaluar el modelo
mse = mean_squared_error(y_test, y_pred)
print("\nEvaluación del modelo de regresión:")
print(f"Error Cuadrático Medio (MSE): {mse:.2f}")
# Out:
# Evaluación del modelo de regresión:
# Error Cuadrático Medio (MSE): 12.16

# %% [markdown]
# # Interpretación:
# Un MSE más bajo indica que el modelo está haciendo predicciones más cercanas a los valores reales.

# %% [markdown]
# # Error Absoluto Medio (MAE)
# Descripción: Mide el promedio de las diferencias absolutas entre valores predichos y reales. Es menos sensible a los errores grandes en comparación con el MSE.

# %%
# Evaluar el modelo
mae = mean_absolute_error(y_test, y_pred)
print("\nEvaluación del modelo de regresión:")
print(f"Error Absoluto Medio (MAE): {mae:.2f}")
# Out:
# Evaluación del modelo de regresión:
# Error Absoluto Medio (MAE): 2.83

# %% [markdown]
# # Interpretación:
# Un MAE más bajo indica que el modelo está haciendo predicciones más precisas en promedio.

# %% [markdown]
# # Coeficiente de Determinación (R²)
# Descripción: Mide la proporción de la varianza en la variable dependiente que es explicada por el modelo. Varía entre 0 (sin explicación) y 1 (explicación perfecta).

# %%
# Evaluar el modelo
r2 = r2_score(y_test, y_pred)

# %%
print("\nEvaluación del modelo de regresión:")
print(f"Coeficiente de Determinación (R²): {r2:.2f}")
# Out:
# Evaluación del modelo de regresión:
# Coeficiente de Determinación (R²): 0.11

# %% [markdown]
# # Interpretación:
# Un R² más alto indica un mejor ajuste del modelo a los datos. Un R² negativo sugiere que el modelo es peor que un modelo simple que predice la media de los valores.

# %% [markdown]
# # Visualización de Predicciones vs. Valores Reales
# Descripción: Un gráfico de dispersión para comparar las predicciones del modelo con los valores reales. La línea de referencia ayuda a visualizar cuán cerca están las predicciones de los valores reales.

# %%
# Visualizar las predicciones vs. valores reales
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='blue', label='Predicciones')
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='red', linestyle='--', label='Línea de referencia')
plt.xlabel('Valores Reales')
plt.ylabel('Valores Predichos')
plt.title('Predicciones vs. Valores Reales')
plt.legend()
plt.show()

# %% [markdown]
# # Distribución de Errores
# Descripción: Un histograma que muestra la distribución de los errores (diferencias entre valores reales y predicciones). La curva KDE (Kernel Density Estimate) ayuda a visualizar la forma de la distribución.

# %%
# Visualizar la distribución de errores
errors = y_test - y_pred
plt.figure(figsize=(10, 6))
sns.histplot(errors, kde=True)
plt.xlabel('Error')
plt.ylabel('Frecuencia')
plt.title('Distribución de Errores')
plt.show()

# %% [markdown]
# # Autoevaluación
#
# 1. **¿Qué métrica mide el promedio de los cuadrados de los errores en las predicciones del modelo?**
#    - A) Error Absoluto Medio (MAE)
#    - **B) Error Cuadrático Medio (MSE)**
#    - C) Coeficiente de Determinación (R²)
#    - D) Error de Predicción
#
# 2. **¿Cuál es la interpretación de un valor bajo de MAE?**
#    - A) El modelo es poco preciso en promedio.
#    - B) El modelo tiene errores grandes en las predicciones.
#    - **C) El modelo es preciso en promedio.**
#    - D) El modelo explica muy bien la varianza en los datos.
#
# 3. **¿Qué indica un valor de R² igual a 1?**
#    - A) El modelo no explica nada de la varianza en los datos.
#    - B) El modelo tiene errores muy altos en las predicciones.
#    - **C) El modelo explica perfectamente la varianza en los datos.**
#    - D) El modelo tiene errores bajos, pero no explica bien los datos.
#
# 4. **¿Cuál es el propósito de dividir los datos en conjuntos de entrenamiento y prueba?**
#    - **A) Para evaluar el rendimiento del modelo en datos no vistos.**
#    - B) Para aumentar el tamaño del conjunto de datos.
#    - C) Para realizar una normalización de datos.
#    - D) Para combinar datos de diferentes fuentes.
#
# 5. **En la visualización de 'Predicciones vs. Valores Reales', ¿qué representa la línea de referencia?**
#    - A) La línea de tendencia de los datos.
#    - B) La media de los valores reales.
#    - **C) La línea donde las predicciones serían perfectas.**
#    - D) La desviación estándar de los errores.
#
# 6. **¿Qué información proporciona el histograma de errores?**
#    - A) La distribución de los valores reales en el conjunto de datos.
#    - B) La relación entre las predicciones y los valores reales.
#    - **C) La distribución de las diferencias entre valores reales y predicciones.**
#    - D) La precisión del modelo en datos de entrenamiento.
#
# 7. **¿Qué métrica es menos sensible a errores grandes y proporciona un promedio simple de las diferencias absolutas?**
#    - A) Error Cuadrático Medio (MSE)
#    - **B) Error Absoluto Medio (MAE)**
#    - C) Coeficiente de Determinación (R²)
#    - D) Error de Predicción
#
# 8. **¿Cuál es la función principal de la biblioteca sklearn en el notebook?**
#    - A) Crear gráficos y visualizaciones.
#    - B) Preprocesar los datos.
#    - **C) Construir y evaluar modelos predictivos.**
#    - D) Leer y escribir archivos CSV.
#
# 9. **¿Qué función se utiliza para calcular el Error Cuadrático Medio en Python?**
#    - A) mean_absolute_error()
#    - B) r2_score()
#    - **C) mean_squared_error()**
#    - D) accuracy_score()
#
# 10. **¿Qué se está intentando predecir en el modelo de regresión lineal?**
#     - A) nota_final
#     - B) nota_diagnostico
#     - C) nota_interciclo
#     - **D) nota_final2**
